# %%
###Project Statement of Work
##Analysis of crime data to find the best and worst locations for property sales
#Stakeholder - Head of sales of a real estate company
#Scope - 4 police services across 2 years - Bedfordshire, Hertfordshire, Metropolitan (London), Thames Valley (Buckinghamshire) from Jan 2024 - Jan 2026

##Deliverables:
#PSOW
#Trello Board
#Jupyter Notebook with preprocessing
#EDA report

# %%
"""crime_df = pd.concat(all_data, ignore_index=True)
crime_df.head()
crime_df.info()
crime_df = crime_df.drop_duplicates()
crime_df["Month"] = pd.to_datetime(crime_df["Month"])
crime_df.to_csv("processedcrime.csv", index=False)"""

##Compiles data, shows top rows, shows row information, removes duplicates, reformatting for month data type, recompiles into new sheet.

# %%
###Crime Data Exploratory Data Analysis
##Real Estate Evaluation by Crime Statistics

#This analysis focuses on UK crime statistics from data.police.uk. These statistics can be used to make inferences on retail desirability. The dataset contains information about crime type, location, and date, per month per service. It compares 4 adjacent police services, Bedfordshire,Hertfordshire, Metropolitan (London), Thames Valley (Buckinghamshire) from January 2024 to January 2026. These services were chosen as their corresponding locations are London and three counties adjacent to London and each other.

#From a first glance it is shown that Bedfordshire and Hertfordshire are the lowest in total crime, so we can focus on these two for further investigation. Upon investigating types of crime in each area, it is shown that the crime types leading the polls are similar, with "violence and sexual offenses" leading by a very wide margin. However, Bedfordshire is consistently lower than Hertfordshire in number of crimes per type, as well as total. Next focusing on the number of crimes per month across the given period, it is shown that crime consistently dips significantly for January and February. Extrapolating from the dataset shows that the most desirable location is Bedfordshire, and the most desirable month for that location would be the start of each new year for January and February.
